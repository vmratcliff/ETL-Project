# %%
import pandas as pd

# %%
path="./hate_crime/hate_crime.csv"

# %%
US_crime=pd.read_csv(path)
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
US_crime.head()
# Out:
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0         3015       1991  AR0040200          Rogers             NaN
# 1         3016       1991  AR0290100            Hope             NaN
# 2           43       1991  AR0350100      Pine Bluff             NaN
# 3           44       1991  AR0350100      Pine Bluff             NaN
# 4         3017       1991  AR0350100      Pine Bluff             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# ...

# %%
US_crime=US_crime[["DATA_YEAR","STATE_NAME","OFFENDER_RACE","OFFENSE_NAME","LOCATION_NAME","BIAS_DESC"]].copy()

# %%
Texas_crime=US_crime[US_crime['STATE_NAME']=='Texas']
Texas_crime.head()
# Out:
#       DATA_YEAR STATE_NAME              OFFENDER_RACE  \
# 4203       1991      Texas                      White
# 4204       1991      Texas                      White
# 4205       1991      Texas                      White
# 4206       1991      Texas  Black or African American
# 4207       1991      Texas                    Unknown
#
#                                   OFFENSE_NAME  \
# 4203                            Simple Assault
# 4204                        Aggravated Assault
# 4205                              Intimidation
# 4206                        Aggravated Assault
# 4207  Destruction/Damage/Vandalism of Property
#
#                                       LOCATION_NAME  \
# 4203  Jail/Prison/Penitentiary/Corrections Facility
# 4204                        Parking/Drop Lot/Garage
# 4205                              Convenience Store
# 4206                                  Other/Unknown
# 4207                                 Residence/Home
#
# ...

# %%
path2="Hate_Crimes_2018_Final.csv"
Austin_crime=pd.read_csv(path2)
Austin_crime.head(10)
# Out:
#       Month Incident Number Date of Incident/Day of Week  \
# 0   January     2018-251458              01 25 2018/Thur
# 1   January     2018-200595               01 19 2018/Fri
# 2  February     2018-400447              02 08 2018/Thur
# 3  February     2018-530804              02 22 2018/Thur
# 4     March     2018-611809               03 02 2018/Fri
# 5     March     2018-651279               03 06 2018/Tue
# 6     March     2018-670117              03 08 2018/Thur
# 7     April     2018-911582               04 01 2018/Sun
# 8     April     2018-120696               04 30 2018/Mon
# 9      May     2018-1410057               05 21 2018/Mon
#
#    Number of vitims under 18  Number of Victims Over 18  \
# 0                          0                          2
# 1                          0                          0
# 2                          0                          1
# 3                          0                          1
# ...

# %%
# Out:
#    Incident Number     Highest Offense Description  Highest Offense Code  \
# 0        201811117              ROBBERY BY ASSAULT                   303
# 1        201810248         CRIMINAL TRESPASS/HOTEL                  2722
# 2        201811933  ASSAULT W/INJURY-FAM/DATE VIOL                   900
# 3      20185000028             BURGLARY OF VEHICLE                   601
# 4        201810183   DOC DISCHARGE GUN - PUB PLACE                  2408
#
#   Family Violence      Occurred Date Time Occurred Date  Occurred Time  \
# 0               N  01/01/2018 11:48:00 AM    01/01/2018           1148
# 1               N  01/01/2018 04:41:00 AM    01/01/2018            441
# 2               Y  01/01/2018 11:16:00 PM    01/01/2018           2316
# 3               N  12/31/2017 11:30:00 PM    12/31/2017           2330
# 4               N  01/01/2018 01:20:00 AM    01/01/2018            120
#
#          Report Date Time Report Date  Report Time  ... Census Tract  \
# ...
